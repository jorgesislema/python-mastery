# %% [markdown]
# # Ejercicios — Backend y APIs
# Nivel: PhD | Actualizado: Septiembre 2026
#
# **Requisitos:** `pip install fastapi uvicorn pydantic httpx pytest`

# %% [markdown]
# ## Ejercicio 1: API REST Completa
# Crea una API CRUD para gestionar productos con FastAPI: (a) `POST /productos` — crear, (b) `GET /productos` — listar, (c) `GET /productos/{id}` — obtener, (d) `PUT /productos/{id}` — actualizar, (e) `DELETE /productos/{id}` — eliminar. Usa Pydantic v3 para validación.

# %%
from fastapi import FastAPI, HTTPException
from pydantic import BaseModel, Field
from datetime import datetime

app = FastAPI(title="Productos API")
db: dict[int, dict] = {}

class Producto(BaseModel):
    nombre: str = Field(..., min_length=1, max_length=100)
    precio: float = Field(..., gt=0)
    descripcion: str = ""

# Completa los endpoints aquí

# %% [markdown]
# ## Ejercicio 2: Autenticación JWT
# Implementa: (a) registro de usuario con hash de contraseña, (b) login que retorne JWT, (c) endpoint protegido que requiera token, (d) refresh token.

# %%
# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 3: Testing de APIs
# Escribe tests para la API del ejercicio 1 usando `httpx.AsyncClient`: (a) test crear producto, (b) test listar productos, (c) test producto no encontrado, (d) test validación de datos.

# %%
import pytest
from httpx import AsyncClient, ASGITransport

# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 4: WebSockets
# Crea un chat en tiempo real con WebSockets: (a) salas de chat, (b) lista de usuarios conectados, (c) mensajes privados, (d) historial de mensajes.

# %%
# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 5: Challenge — Microservicio con FastAPI + SQLAlchemy
# Diseña un microservicio completo: (a) PostgreSQL con SQLAlchemy 2.x, (b) migraciones con Alembic, (c) endpoints REST, (d) autenticación JWT, (e) Dockerfile + docker-compose, (f) tests.

# %%
# Escribe tu código aquí
