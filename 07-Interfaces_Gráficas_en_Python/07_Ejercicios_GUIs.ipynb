# %% [markdown]
# # Ejercicios — Interfaces Gráficas
# Nivel: PhD | Actualizado: Septiembre 2026
#
# **Requisitos:** `pip install streamlit tkinter`

# %% [markdown]
# ## Ejercicio 1: Tkinter — Gestor de Tareas
# Crea una app de gestión de tareas con: (a) Treeview para listar tareas, (b) formulario para agregar (nombre, prioridad, fecha), (c) botón eliminar, (d) menú contextual, (e) exportar a CSV.

# %%
import tkinter as tk
from tkinter import ttk, messagebox, filedialog

# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 2: Streamlit Dashboard
# Crea un dashboard interactivo que: (a) suba CSV, (b) muestre KPIs, (c) permita filtrar por columnas, (d) gráficos dinámicos con Plotly, (e) exportar datos filtrados.

# %%
import streamlit as st

# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 3: PyQt6 — Visor de Datos
# Crea un visor de datos con: (a) tabla con búsqueda en tiempo real, (b) filtros por columna, (c) gráfico matplotlib embebido, (d) barra de estado, (e) exportar selección.

# %%
# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 4: Challenge — Monitor de Sistema
# Crea un monitor de sistema en tiempo real: (a) CPU y memoria cada 1s, (b) gráfico de línea en vivo, (c) alertas si supera umbrales, (d) historial exportable. Usa Tkinter o PyQt6.

# %%
# Escribe tu código aquí
