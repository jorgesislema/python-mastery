# %% [markdown]
# # Ejercicios — Tendencias 2025-2026
# Nivel: PhD | Actualizado: Septiembre 2026
#
# **Requisitos:** `pip install polars langchain openai pydantic`

# %% [markdown]
# ## Ejercicio 1: Polars vs Pandas
# Compara rendimiento: (a) lee un CSV de 1M filas con ambos, (b) filtra + agrupa + ordena, (c) mide tiempo y memoria. ¿Cuánto más rápido es Polars?

# %%
import pandas as pd
import polars as pl
import numpy as np
import time

# Genera dataset grande
np.random.seed(42)
n = 1_000_000
df_pd = pd.DataFrame({
    "id": range(n),
    "categoria": np.random.choice(["A","B","C","D","E"], n),
    "valor": np.random.randn(n),
    "fecha": pd.date_range("2020-01-01", periods=n, freq="min"),
})
df_pl = pl.from_pandas(df_pd)

# Guarda como CSV para comparar lectura
df_pd.to_csv("datos_grandes.csv", index=False)

# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 2: Pydantic v3 — Validación Avanzada
# Crea un modelo `Usuario` con: (a) email validado, (b) contraseña fuerte (>8 chars, mayúscula, número, símbolo), (c) fecha de nacimiento que calcule la edad, (d) roles con restricciones. Incluye validadores custom.

# %%
from pydantic import BaseModel, Field, field_validator, model_validator
from typing import Annotated
from datetime import datetime

# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 3: LangChain — RAG Simple
# Implementa un sistema RAG con: (a) documentos de texto chunk, (b) embeddings con sentence-transformers, (c) búsqueda por similaridad coseno, (d) generación de respuesta con contexto.

# %%
# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 4: MCP Server
# Crea un servidor MCP que exponga: (a) herramienta `buscar_en_csv(path, query)`, (b) herramienta `calcular_estadisticas(csv, columna)`, (c) recurso `listar_archivos(directorio)`. Incluye documentación completa.

# %%
# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 5: Challenge — Agente Autónomo con LangGraph
# Implementa un agente que: (a) reciba una tarea en lenguaje natural, (b) la descomponga en pasos, (c) ejecute cada paso usando herramientas, (d) valide el resultado, (e) reintente si falla. Usa LangGraph para el grafo de estados.

# %%
# Escribe tu código aquí
