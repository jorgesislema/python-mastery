# %% [markdown]
# # Ejercicios — Visualización de Datos
# Nivel: PhD | Actualizado: Septiembre 2026
#
# **Requisitos:** `pip install matplotlib seaborn plotly pandas numpy`

# %% [markdown]
# ## Ejercicio 1: Dashboard Completo con Matplotlib
# Crea un dashboard 2x2 con GridSpec: (a) línea de tendencia con intervalo de confianza, (b) histograma con KDE superpuesto, (c) barras horizontales con valores anotados, (d) scatter con color y tamaño. Usa una paleta de colores coherente.

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import pandas as pd

np.random.seed(42)
df = pd.DataFrame({
    "fecha": pd.date_range("2024-01-01", periods=365),
    "ventas": np.cumsum(np.random.randn(365) * 100 + 50),
    "producto": np.random.choice(["A", "B", "C"], 365),
    "region": np.random.choice(["Norte", "Sur", "Este", "Oeste"], 365),
    "precio": np.random.uniform(10, 100, 365),
    "cantidad": np.random.randint(1, 50, 365),
})

# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 2: Análisis Estadístico con Seaborn
# Con el dataset de diamantes de seaborn: (a) jointplot de precio vs quilates, (b) boxplot por color, (c) violin plot combinado con strip plot, (d) pair plot de las variables numéricas. Incluye títulos descriptivos.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

diamonds = sns.load_dataset("diamonds")

# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 3: Visualización Interactiva con Plotly
# Crea: (a) gráfico de dispersión animado (evolución temporal), (b) treemap jerárquico, (c) sunburst, (d) heatmap interactivo con hover. Usa el dataset de gapminder.

# %%
import plotly.express as px
import plotly.graph_objects as go

gapminder = px.data.gapminder()

# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 4: Storytelling — Antes vs Después
# Toma un gráfico mal diseñado (barras 3D con colores arcoíris) y rediséñalo siguiendo principios de storytelling. Documenta qué cambiaste y por qué.

# %%
# Escribe tu código aquí

# %% [markdown]
# ## Ejercicio 5: Challenge — Generador de Reportes
# Crea una función `generar_reporte(df, titulo)` que: (a) detecte automáticamente columnas numéricas/categóricas, (b) genere gráficos apropiados para cada tipo, (c) exporte un HTML con todos los gráficos embebidos.

# %%
# Escribe tu código aquí
