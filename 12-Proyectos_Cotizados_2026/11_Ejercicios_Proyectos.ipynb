# %% [markdown]
# # Proyectos Cotizados 2026 — Ejercicios Prácticos
# Resuelve al menos 3 proyectos para tener un portfolio sólido.
# Cada proyecto incluye la implementación base — tú completas la lógica.

# %% [markdown]
# ---
# ## Proyecto 1: RAG Básico
#
# **Objetivo:** Crea un sistema que responda preguntas sobre documentos PDF.
#
# **Pasos:**
# 1. Carga un PDF con PyMuPDF
# 2. Divide en chunks de 1000 caracteres
# 3. Crea embeddings con sentence-transformers
# 4. Busca los 5 chunks más similares
# 5. Genera respuesta con OpenAI
#
# **Librerías:** `pip install pymupdf sentence-transformers openai chromadb`

# %%
# Implementa tu RAG básico aquí
# Paso 1: Carga un PDF
# Paso 2: Divide en chunks
# Paso 3: Crea embeddings
# Paso 4: Busca similares
# Paso 5: Genera respuesta

# %% [markdown]
# ---
# ## Proyecto 2: Trading Bot Simple
#
# **Objetivo:** Crea un bot que compre/venda basado en RSI.
#
# **Regla:** Comprar cuando RSI < 30, vender cuando RSI > 70.
#
# **Pasos:**
# 1. Obtén datos históricos con ccxt
# 2. Calcula RSI con ta
# 3. Simula trades (sin dinero real)
# 4. Calcula retorno total vs buy-and-hold
# 5. Grafica el equity curve
#
# **Librerías:** `pip install ccxt ta polars plotly`

# %%
import ccxt
import polars as pl
import numpy as np

# Implementa tu trading bot aquí
# Paso 1: Obtén datos
# Paso 2: Calcula RSI
# Paso 3: Genera señales
# Paso 4: Simula trades
# Paso 5: Calcula métricas

# %% [markdown]
# ---
# ## Proyecto 3: Sentiment Analysis API
#
# **Objetivo:** API que analice sentimiento de texto.
#
# **Pasos:**
# 1. Entrena o usa un modelo pre-entrenado
# 2. Crea endpoint POST /analyze
# 3. Retorna: sentimiento, confidence, scores
# 4. Agrega batch processing
# 5. Rate limiting por usuario
#
# **Librerías:** `pip install transformers fastapi uvicorn`

# %%
from transformers import pipeline
from fastapi import FastAPI

# Implementa tu sentiment API aquí

# %% [markdown]
# ---
# ## Proyecto 4: MLOps Pipeline
#
# **Objetivo:** Pipeline completo de ML con tracking.
#
# **Pasos:**
# 1. Genera dataset sintético
# 2. Entrena 3 modelos (Logistic, RF, XGBoost)
# 3. Loguea en MLflow
# 4. Selección del mejor modelo
# 5. Exporta con joblib
# 6. Crea endpoint de predicción
#
# **Librerías:** `pip install mlflow scikit-learn xgboost fastapi`

# %%
import mlflow
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier

# Implementa tu MLOps pipeline aquí

# %% [markdown]
# ---
# ## Proyecto 5: Web Scraper + LLM Resumen
#
# **Objetivo:** Scrapea noticias y genera resúmenes automáticos.
#
# **Pasos:**
# 1. Scrapea 5 artículos con Playwright
# 2. Extrae texto limpio
# 3. Resume cada uno con OpenAI
# 4. Clasifica por categoría
# 5. Genera informe HTML
#
# **Librerías:** `pip install playwright openai beautifulsoup4`

# %%
# Implementa tu scraper + LLM aquí

# %% [markdown]
# ---
# ## Proyecto 6: Dashboard Financiero
#
# **Objetivo:** Dashboard interactivo con datos de mercado.
#
# **Pasos:**
# 1. Conecta a API de Binance (ccxt)
# 2. Muestra precio en tiempo real
# 3. Gráfico de velas con Plotly
# 4. Indicadores: RSI, MACD, Bollinger
# 5. Alertas cuando RSI < 30 o > 70
#
# **Librerías:** `pip install ccxt plotly streamlit ta`

# %%
import streamlit as st
import plotly.graph_objects as go

# Implementa tu dashboard aquí

# %% [markdown]
# ---
# ## Proyecto 7: Chatbot con Memoria
#
# **Objetivo:** Chatbot que recuerde conversaciones anteriores.
#
# **Pasos:**
# 1. Mantén historial en Redis
# 2. Incluye últimas 10 mensajes en el contexto
# 3. Responde con OpenAI
# 4. Guarda cada interacción
# 5. Resume conversación larga cada 20 mensajes
#
# **Librerías:** `pip install openai redis fastapi`

# %%
import redis
from openai import OpenAI

# Implementa tu chatbot con memoria aquí

# %% [markdown]
# ---
# ## Proyecto 8: Data Pipeline con Polars
#
# **Objetivo:** Pipeline ETL ultrarrápido.
#
# **Pasos:**
# 1. Lee 3 CSVs grandes con Polars (lazy)
# 2. Limpia: nulos, duplicados, tipos
# 3. Transforma: agrupaciones, joins, window functions
# 4. Exporta a Parquet
# 5. Compara tiempo con Pandas
#
# **Librerías:** `pip install polars pandas`

# %%
import polars as pl
import time

# Implementa tu data pipeline aquí

# %% [markdown]
# ---
# ## Proyecto 9: Computer Vision con YOLO
#
# **Objetivo:** Detecta objetos en imágenes/video.
#
# **Pasos:**
# 1. Carga modelo YOLO pre-entrenado
# 2. Detecta objetos en una imagen
# 3. Dibuja bounding boxes
# 4. Procesa un video completo
# 5. Cuenta objetos por frame
#
# **Librerías:** `pip install ultralytics opencv-python`

# %%
from ultralytics import YOLO

# Implementa tu CV pipeline aquí

# %% [markdown]
# ---
# ## Proyecto 10: AI SaaS Mínimo
#
# **Objetivo:** MVP de un SaaS con IA.
#
# **Pasos:**
# 1. Auth con JWT (registro + login)
# 2. Rate limiting por usuario
# 3. Feature IA: análisis de texto
# 4. Billing mock (free vs pro)
# 5. Admin dashboard con métricas
#
# **Librerías:** `pip install fastapi uvicorn pydantic python-jose passlib`

# %%
from fastapi import FastAPI, Depends, HTTPException
from pydantic import BaseModel

# Implementa tu AI SaaS MVP aquí
